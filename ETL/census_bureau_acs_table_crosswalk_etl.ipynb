# %% [markdown]
# # Census Bureau ACS Table Crosswalk
#
# Looks for correlated tables inside both Census Bureau ACS 5yr and ACS Supplemental Estimate 1yr datasets that can be compared against one another.
#
# Note: requires ACS and ACSSE databases to be stored locally in `data/databases` directory before running.

# %%
import pandas as pd
import os
import sqlalchemy

# %% [markdown]
# ## User Variables

# %%
acs_survey_year = '2022'
acsse_survey_year = '2022'

# %% [markdown]
# ## Extract

# %%
# imports Census survey data
acs_db_filepath = os.path.join(f'data/databases/census_bureau/census_acs5_{acs_survey_year}_block_group.db')
acs_sql_engine = sqlalchemy.create_engine('sqlite:///' + acs_db_filepath)
acs_tables = pd.read_sql_table('tables', acs_sql_engine)
acs_tables.head()
# Out:
#    index      name                                            concept
# 0      4    B24022  sex_by_occupation_and_median_earnings_in_the_p...
# 1      5   B19001B  household_income_in_the_past_12_months_(in_202...
# 2      6  B07007PR  geographical_mobility_in_the_past_year_by_citi...
# 3      7   B19101A  family_income_in_the_past_12_months_(in_2022_i...
# 4     14   B01001B       sex_by_age_(black_or_african_american_alone)

# %%
acsse_db_filepath = os.path.join(f'data/databases/census_bureau/census_acsse_{acsse_survey_year}_congressional_district.db')
# creates connection to SQLite database
acsse_sql_engine = sqlalchemy.create_engine('sqlite:///' + acsse_db_filepath)
acsse_tables = pd.read_sql_table('tables', acsse_sql_engine)
acsse_tables.head()
# Out:
#    index     name                                            concept
# 0      4  K202101  veteran_status_for_the_civilian_population_18_...
# 1      5  K200201                                               race
# 2      6  K202505                               year_structure_built
# 3     11  K201802               work_experience_by_disability_status
# 4     12  K200104                                  population_by_age

# %% [markdown]
# ## Transform

# %%
matching_acs_index_list = []
matching_acsse_index_list = []
for acsse_index, acsse_concept in acsse_tables['concept'].items():
    for acs_index, acs_concept in acs_tables['concept'].items():    
        if acsse_concept == acs_concept:
            matching_acs_index_list.append(acs_index)
            matching_acsse_index_list.append(acsse_index)

# %%
matching_acs_tables = acs_tables.iloc[matching_acs_index_list]
matching_acs_tables['acs_5yr_table_name'] = matching_acs_tables['name']
# Out:
# /var/folders/p1/8fyq7zs911z9m3y9xhtyw6nh0000gn/T/ipykernel_36159/600337865.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_acs_tables['acs_5yr_table_name'] = matching_acs_tables['name']

# %%
matching_acsse_tables = acsse_tables.iloc[matching_acsse_index_list]
matching_acsse_tables['acs_1yr_table_name'] = matching_acsse_tables['name']
# Out:
# /var/folders/p1/8fyq7zs911z9m3y9xhtyw6nh0000gn/T/ipykernel_36159/538612201.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matching_acsse_tables['acs_1yr_table_name'] = matching_acsse_tables['name']

# %%
# merges our two tables
matching_tables = matching_acs_tables.merge(acsse_tables, how='left', on='concept')
matching_tables
# Out:
#     index_x  name_x                                            concept  \
# 0     27074  B02001                                               race
# 1      3898  B25034                               year_structure_built
# 2     10187  B14001  school_enrollment_by_level_of_school_for_the_p...
# 3     22226  B15003  educational_attainment_for_the_population_25_y...
# 4     26686  B26001                          group_quarters_population
# 5     19081  B09001                   population_under_18_years_by_age
# 6     16351  B19202  median_nonfamily_household_income_in_the_past_...
# 7      3185  B20017  median_earnings_in_the_past_12_months_(in_2022...
# 8     11939  B25008  total_population_in_occupied_housing_units_by_...
# 9     24809  B08303                                travel_time_to_work
# 10    27778  B01002                                  median_age_by_sex
# 11    26492  B19013  median_household_income_in_the_past_12_months_...
# 12    15792  B17020        poverty_status_in_the_past_12_months_by_age
# 13     4965  B25002                                   occupancy_status
# 14     3570  B98003                 unweighted_total_population_sample
# 15     9631  B25081                                    mortgage_status
# 16     7398  B03003                          hispanic_or_latino_origin
# 17     1546  B11006  households_by_presence_of_people_60_years_and_...
# 18     1025  B25077                             median_value_(dollars)
# 19     4460  B19101  family_income_in_the_past_12_months_(in_2022_i...
# 20    19038  B23025  employment_status_for_the_population_16_years_...
# 21    15583  B25063                                         gross_rent
# 22    15145  B98001                     unweighted_housing_unit_sample
# 23    12088  B08301                    means_of_transportation_to_work
# 24    23188  B19001  household_income_in_the_past_12_months_(in_202...
# 25     2086  B19113  median_family_income_in_the_past_12_months_(in...
# 26    25526  B25064                        median_gross_rent_(dollars)
# 27    17891  B25024                                 units_in_structure
# 28    14376  B28003  presence_of_a_computer_and_type_of_internet_su...
# 29    20823  B28008  presence_of_a_computer_and_type_of_internet_su...
#
#    acs_5yr_table_name  index_y   name_y
# 0              B02001        5  K200201
# 1              B25034        6  K202505
# 2              B14001       14  K201401
# 3              B15003       49  K201501
# 4              B26001       50  K202601
# 5              B09001       67  K200102
# 6              B19202       79  K201905
# 7              B20017       81  K202002
# 8              B25008       83  K202503
# 9              B08303      154  K200802
# 10             B01002      158  K200103
# 11             B19013      182  K201902
# 12             B17020      185  K201701
# 13             B25002      186  K202501
# 14             B98003      190  K209803
# 15             B25081      192  K202508
# 16             B03003      202  K200301
# 17             B11006      206  K201102
# 18             B25077      214  K202510
# 19             B19101      230  K201903
# 20             B23025      282  K202301
# 21             B25063      283  K202507
# 22             B98001      284  K209801
# 23             B08301      290  K200801
# 24             B19001      293  K201901
# 25             B19113      295  K201904
# 26             B25064      320  K202511
# 27             B25024      331  K202504
# 28             B28003      333  K202801
# 29             B28008      333  K202801

# %%
# removes `index` and old 'name' columns
matching_tables.drop(columns=['index_x', 'index_y', 'name_x'], inplace=True)
matching_tables.rename(columns={'name_y': 'acs_1yr_table_name'}, inplace=True)
matching_tables
# Out:
#                                               concept acs_5yr_table_name  \
# 0                                                race             B02001
# 1                                year_structure_built             B25034
# 2   school_enrollment_by_level_of_school_for_the_p...             B14001
# 3   educational_attainment_for_the_population_25_y...             B15003
# 4                           group_quarters_population             B26001
# 5                    population_under_18_years_by_age             B09001
# 6   median_nonfamily_household_income_in_the_past_...             B19202
# 7   median_earnings_in_the_past_12_months_(in_2022...             B20017
# 8   total_population_in_occupied_housing_units_by_...             B25008
# 9                                 travel_time_to_work             B08303
# 10                                  median_age_by_sex             B01002
# 11  median_household_income_in_the_past_12_months_...             B19013
# 12        poverty_status_in_the_past_12_months_by_age             B17020
# 13                                   occupancy_status             B25002
# 14                 unweighted_total_population_sample             B98003
# 15                                    mortgage_status             B25081
# 16                          hispanic_or_latino_origin             B03003
# 17  households_by_presence_of_people_60_years_and_...             B11006
# 18                             median_value_(dollars)             B25077
# 19  family_income_in_the_past_12_months_(in_2022_i...             B19101
# 20  employment_status_for_the_population_16_years_...             B23025
# 21                                         gross_rent             B25063
# 22                     unweighted_housing_unit_sample             B98001
# 23                    means_of_transportation_to_work             B08301
# 24  household_income_in_the_past_12_months_(in_202...             B19001
# 25  median_family_income_in_the_past_12_months_(in...             B19113
# 26                        median_gross_rent_(dollars)             B25064
# 27                                 units_in_structure             B25024
# 28  presence_of_a_computer_and_type_of_internet_su...             B28003
# 29  presence_of_a_computer_and_type_of_internet_su...             B28008
#
#    acs_1yr_table_name
# 0             K200201
# 1             K202505
# 2             K201401
# 3             K201501
# 4             K202601
# 5             K200102
# 6             K201905
# 7             K202002
# 8             K202503
# 9             K200802
# 10            K200103
# 11            K201902
# 12            K201701
# 13            K202501
# 14            K209803
# 15            K202508
# 16            K200301
# 17            K201102
# 18            K202510
# 19            K201903
# 20            K202301
# 21            K202507
# 22            K209801
# 23            K200801
# 24            K201901
# 25            K201904
# 26            K202511
# 27            K202504
# 28            K202801
# 29            K202801

# %% [markdown]
# ## Load

# %%
databases_dirpath = os.path.join('data/databases/census_bureau')
crosswalk_db_filepath = os.path.join(databases_dirpath, f'census_acs-acsse_crosswalk.db')
crosswalk_sql_engine = sqlalchemy.create_engine('sqlite:///' + crosswalk_db_filepath)
matching_tables.to_sql(f'acs_{acs_survey_year}-acsse_{acsse_survey_year}_crosswalk', crosswalk_sql_engine, if_exists='replace')
# Out:
# 30
